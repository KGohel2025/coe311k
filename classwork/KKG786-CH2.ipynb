# %%
import math
 
x = int(input("Enter a number: "))

den= 2
div = math.trunc(x/den)
ans = x - (den *div)
answer = str(ans)
x = div
while x>1: 
    

    den= 2

    div = math.trunc(x/den)
    ans = x - (den *div)
    answer += str(ans)
    x=div
final = answer[::-1]
print (final)
# Out:
# Enter a number: 2025
# 1111101001
