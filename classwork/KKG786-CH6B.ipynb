# %%
import time
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if not np.isfinite(x_new).all():
            print("Jacobi diverged at iteration", k)
            return x_new, k
            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations



def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        if not np.isfinite(x_new).all():
            print("Jacobi diverged at iteration", k)
            return x_new, k
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations




# Part A
 
A = np.array([[1, 2, 3, 0, 0],[2, 1, 2, 3, 0],[3, 2, 1, 2, 3],[0, 3, 2, 1, 2],[0, 0, 3, 2, 1]], dtype = float)
b = np.array([14, 22, 33, 26, 22], dtype = float )

x0 = np.zeros_like(b, dtype = float)
tol = 1e-6
max_iterations = 100


#Jacobi
t0 = time.perf_counter()
solution_j, iterations_j = jacobi(A, b, x0, tol, max_iterations)
t1 = time.perf_counter()

residual_j = b - A @ solution_j
resnorm_j = np.linalg.norm(residual_j, ord=np.inf)

print("Jacobi")
print("Solution ", solution_j)
print("Number of Iterations ", iterations_j)
print("Time in seconds ", t1 - t0)
print("Residual ", resnorm_j)


# Gauss-Seidel 
t0 = time.perf_counter()
solution_gs, iterations_gs = gauss_seidel(A, b, x0, tol, max_iterations)
t1 = time.perf_counter()

residual_gs = b - A @ solution_gs
resnorm_gs = np.linalg.norm(residual_gs, ord=np.inf)

print("Gauss-Seidel")
print("Solution ", solution_gs)
print("Number of Iterations ", iterations_gs)
print("Time ", t1 - t0)
print("Residual ", resnorm_gs)


# the comparition
print("\nConvergence Comparison")
prin= ""
if iterations_gs < iterations_j :
    prin = "Gauss-Seidel"
else :
    prin = "Jacobi"
print("The one with fewer iterations is ", prin)
# Out:
# Jacobi
# Solution  [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Number of Iterations  100
# Time in seconds  0.0074163768440485
# Residual  4.2867698371802995e+86
# Gauss-Seidel
# Solution  [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Number of Iterations  100
# Time  0.011141328606754541
# Residual  5.073642008248027e+114
#
# Convergence Comparison
# The one with fewer iterations is  Jacobi
